# %%
import os, sys
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
print(parent_dir)
sys.path.insert(0, parent_dir)
# Out:
# c:\Users\hello\Desktop\git\Stock-market-data-analysis-and-prediction

# %%
from scripts.task3_merger import merge

# %%
stocks='../Data/yfinance_data/yfinance_data/AAPL_historical_data.csv'
news='../Data/raw_analyst_ratings.csv/raw_analyst_ratings (Autosaved).csv'
df_news,df_stock= merge.load_datas(news,stocks)
df_news,df_stock
# Out:
# (         Unnamed: 0                                           headline  \
#  0                 0            Stocks That Hit 52-Week Highs On Friday
#  1                 1         Stocks That Hit 52-Week Highs On Wednesday
#  2                 2                      71 Biggest Movers From Friday
#  3                 3       46 Stocks Moving In Friday's Mid-Day Session
#  4                 4  B of A Securities Maintains Neutral on Agilent...
#  ...             ...                                                ...
#  1048570     1053768  First Horizon National to Replace QLogic in S&...
#  1048571     1053769  UPDATE: QLogic Announces Restructuring Plan, t...
#  1048572     1053770  QLogic Announces Restructuring Plan, to Cut Jo...
#  1048573     1053771  QLogic Corporation Reports Q4 EPS of $0.17 vs ...
#  1048574     1053772     QLogic Reports New $125M Revolving Credit Line
#
#                                                         url          publisher  \
# ...

# %%
combined=merge.combine(df_news,df_stock,'AAPL')
combined
# Out:
# c:\Users\hello\Desktop\git\Stock-market-data-analysis-and-prediction\scripts\task3_merger.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.drop(columns=['date'], inplace=True)
#       Unnamed: 0                                           headline  \
# 6414        7120  Tech Stocks And FAANGS Strong Again To Start D...
# 6415        7121      10 Biggest Price Target Changes For Wednesday
# 6416        7122  Benzinga Pro's Top 5 Stocks To Watch For Wed.,...
# 6417        7123  Deutsche Bank Maintains Buy on Apple, Raises P...
# 6418        7124  Apple To Let Users Trade In Their Mac Computer...
# ...          ...                                                ...
# 6824        7585  UBS Maintains Buy on Apple, Lowers Price Targe...
# ...

# %%
with_sentiment= merge.call_sentiment_analysis(df_news,df_stock,combined)
with_sentiment
# Out:
#       Unnamed: 0                                           headline  \
# 6414        7120  Tech Stocks And FAANGS Strong Again To Start D...
# 6420        7126          Why Apple's Stock Is Trading Higher Today
# 6424        7159  'Apple is tracking iPhones stolen by looters' ...
# 6430        7165  Apple Cuts iPhone Prices in China To Push Sale...
# 6436        7173  Costco Shares Come Under Pressure Despite Stro...
# ...          ...                                                ...
# 6788        7549  Canopy Growth's Storz & Bickel Bypasses Apple'...
# 6799        7560  Selling Picks Up In Worst Day Since 1987 As Fe...
# 6804        7565  CME To Shut Down Chicago Trading Floor Over Co...
# 6818        7579  Peloton Shares Tick To Session Low As Hearing ...
# 6826        7587  Crude Awakening: Energy Sector Takes A 20% Spi...
#
#                                                     url          publisher  \
# ...

# %%
with_daily_return=merge.final(df_news,df_stock,with_sentiment)
with_daily_return
# Out:
# c:\Users\hello\Desktop\git\Stock-market-data-analysis-and-prediction\scripts\task3_merger.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Daily Return'] = df['Close'].pct_change()
#            Date      Close     score sentiment  Daily Return
# 6414 2020-06-10  88.209999  0.198850  Positive           NaN
# 6420 2020-06-09  85.997498  0.246900  Positive     -0.025082
# 6424 2020-06-02  80.834999 -0.408683  Negative     -0.060031
# 6430 2020-06-01  80.462502 -0.305667  Negative     -0.004608
# 6436 2020-05-29  79.485001 -0.402300  Negative     -0.012149
# ...         ...        ...       ...       ...           ...
# 6788 2020-03-13  69.492500 -0.059727  Negative      0.147640
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data_to_plot = with_daily_return[['score', 'Daily Return']]

# Print the correlation
correlation = data_to_plot['score'].corr(data_to_plot['Daily Return'])
print("Correlation between sentiment and daily stock returns:", correlation)

# Plot the pairplot
sns.pairplot(data_to_plot)
plt.show()
# Out:
# Correlation between sentiment and daily stock returns: 0.17506676027417611
