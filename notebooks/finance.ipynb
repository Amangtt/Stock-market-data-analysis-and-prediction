# %%
import os, sys
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
print(parent_dir)
sys.path.insert(0, parent_dir)
# Out:
# c:\Users\hello\Desktop\git\Stock-market-data-analysis-and-prediction

# %%
#Loading data
from scripts.finance import financial_analysis
analyzer=financial_analysis
file= 'C:/Users/hello/Desktop/Data/yfinance_data/yfinance_data/AAPL_historical_data.csv'
df= analyzer.load_data(file)
df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...           ...         ...         ...         ...         ...         ...
# 10993  2024-07-24  224.000000  224.800003  217.130005  218.539993  218.287323
# 10994  2024-07-25  218.929993  220.850006  214.619995  217.490005  217.238556
# 10995  2024-07-26  218.699997  219.490005  216.009995  217.960007  217.708008
# 10996  2024-07-29  216.960007  219.300003  215.750000  218.240005  217.987686
# 10997  2024-07-30  219.190002  220.330002  216.119995  218.800003  218.547043
#
# ...

# %%
#printing descrption about our dataset
print(df.describe())  
print(df.info())
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  10998.000000  10998.000000  10998.000000  10998.000000  10998.000000
# mean      22.299160     22.539055     22.068367     22.312754     21.494496
# std       46.003685     46.496031     45.540929     46.037660     45.561916
# min        0.049665      0.049665      0.049107      0.049107      0.037857
# 25%        0.299107      0.303710      0.290179      0.298549      0.241840
# 50%        0.531250      0.537946      0.522321      0.531250      0.432079
# 75%       20.204196     20.389554     19.998036     20.196160     17.253029
# max      236.479996    237.229996    233.089996    234.820007    234.548523
#
#              Volume     Dividends  Stock Splits
# count  1.099800e+04  10998.000000  10998.000000
# mean   3.180806e+08      0.000752      0.001546
# std    3.354523e+08      0.011753      0.083663
# min    0.000000e+00      0.000000      0.000000
# ...

# %%
#Checking the existance of specific columns open,close,high and low
result= analyzer.check_existance(df)
result
# Out:
# True

# %%
#Plotting the graph for 4 columns
OHLC=analyzer.OHLC(df)
OHLC
# Out:
# c:\Users\hello\Desktop\git\Stock-market-data-analysis-and-prediction\scripts\finance.py:45: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Technical analysis with TAlib
TA= analyzer.calculate_technical_indicators(df)
TA
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 33    1981-01-30    0.127232    0.127232    0.126116    0.126116    0.097223
# 34    1981-02-02    0.119420    0.119420    0.118862    0.118862    0.091630
# 35    1981-02-03    0.123326    0.123884    0.123326    0.123326    0.095072
# 36    1981-02-04    0.127790    0.128348    0.127790    0.127790    0.098513
# 37    1981-02-05    0.127790    0.128906    0.127790    0.127790    0.098513
# ...          ...         ...         ...         ...         ...         ...
# 10993 2024-07-24  224.000000  224.800003  217.130005  218.539993  218.287323
# 10994 2024-07-25  218.929993  220.850006  214.619995  217.490005  217.238556
# 10995 2024-07-26  218.699997  219.490005  216.009995  217.960007  217.708008
# 10996 2024-07-29  216.960007  219.300003  215.750000  218.240005  217.987686
# 10997 2024-07-30  219.190002  220.330002  216.119995  218.800003  218.547043
#
# ...

# %%
#Plotting graphs for SMA, EMA, RSI, MACD and MACD_SIGNAL just change the parameter to see the graphs of different indicators
sma=analyzer.plot_TI(df,'SMA')
sma

# %%
# Calculating and Visualizing 3 different finacial meterics like Daily return, Cumilative return and annualized volitilty
analyzer.metrics(TA)
# Out:
# c:\Users\hello\Desktop\git\Stock-market-data-analysis-and-prediction\scripts\finance.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
# c:\Users\hello\Desktop\git\Stock-market-data-analysis-and-prediction\scripts\finance.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['Date'].dt.year
# c:\Users\hello\Desktop\git\Stock-market-data-analysis-and-prediction\scripts\finance.py:63: SettingWithCopyWarning:
# ...
