# %%
import os, sys
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
print(parent_dir)
sys.path.insert(0, parent_dir)
# Out:
# /Users/amantebeje/Desktop/projects/Stock-market-data-analysis-and-prediction

# %%
#Loading data
from scripts.finance import financial_analysis
from scripts.logger import SetupLogger
logger = SetupLogger(log_file='../logs/notebooks.log').get_logger()
analyzer=financial_analysis(logger)
path='../Data/TSLA'
df= analyzer.load_data('TSLA','2011-05-12','2025-01-31',path)
df
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price       Date       Close        High         Low        Open    Volume
# 0     2011-05-12    1.844667    1.849333    1.776667    1.804667   9420000
# 1     2011-05-13    1.836667    1.879333    1.820000    1.866667   9922500
# 2     2011-05-16    1.773333    1.866000    1.770000    1.866000  11335500
# 3     2011-05-17    1.730667    1.800000    1.714667    1.800000  18513000
# 4     2011-05-18    1.756667    1.764667    1.701333    1.740000  10942500
# ...          ...         ...         ...         ...         ...       ...
# 3446  2025-01-24  406.579987  418.880005  405.779999  414.450012  56427100
# 3447  2025-01-27  397.149994  406.690002  389.000000  394.799988  58125500
# 3448  2025-01-28  398.089996  400.589996  386.500000  396.910004  48910700
# 3449  2025-01-29  389.100006  398.589996  384.480011  395.209991  68033600
# 3450  2025-01-30  400.279999  412.500000  384.410004  410.779999  98092900
#
# [3451 rows x 6 columns]

# %%
#Checking the existance of specific columns open,close,high and low
result= analyzer.check_existance()
result
# Out:
# True

# %%
#Plotting the graph for 4 columns
analyzer.closing('TSLA')

# %%
analyzer.rolling_avg()

# %%
analyzer.outliers()

# %%
#Technical analysis with TAlib
TA= analyzer.calculate_technical_indicators()
TA
# Out:
# Price       Date       Close        High         Low        Open    Volume  \
# 0     2011-06-30    1.942000    1.955333    1.893333    1.900000  14200500
# 1     2011-07-01    1.934667    1.973333    1.920000    1.938000  12823500
# 2     2011-07-05    1.942667    1.968000    1.914000    1.934667  14940000
# 3     2011-07-06    1.930667    1.942667    1.903333    1.942667  13903500
# 4     2011-07-07    1.982000    2.000000    1.934000    1.942667  19918500
# ...          ...         ...         ...         ...         ...       ...
# 3412  2025-01-24  406.579987  418.880005  405.779999  414.450012  56427100
# 3413  2025-01-27  397.149994  406.690002  389.000000  394.799988  58125500
# 3414  2025-01-28  398.089996  400.589996  386.500000  396.910004  48910700
# 3415  2025-01-29  389.100006  398.589996  384.480011  395.209991  68033600
# 3416  2025-01-30  400.279999  412.500000  384.410004  410.779999  98092900
#
# Price  Rolling mean  Rolling std  Daily_Return   Z_Score  Outlier         SMA  \
# 0          1.861714     0.043198      2.969247  0.767455    False    1.836800
# 1          1.878952     0.045022     -0.377602 -0.166758    False    1.853600
# 2          1.892572     0.048172      0.413509  0.054067    False    1.874467
# 3          1.905810     0.043146     -0.617706 -0.233779    False    1.884000
# 4          1.927429     0.036643      2.658819  0.680805    False    1.900800
# ...             ...          ...           ...       ...      ...         ...
# 3412     418.097142     8.178253     -1.406474 -0.453949    False  412.108997
# 3413     413.658569     9.997560     -2.319345 -0.708761    False  412.349997
# 3414     411.411425    11.595358      0.236687  0.004710    False  411.827997
# 3415     406.068569    12.090116     -2.258281 -0.691716    False  411.101999
# 3416     402.669996     9.179952      2.873295  0.740672    False  408.307999
#
# Price         EMA        RSI      MACD  MACD_SIGNAL
# 0        1.863165  62.313489  0.004972    -0.006313
# 1        1.876166  61.030654  0.010077    -0.003035
# 2        1.888257  61.979447  0.014600     0.000492
# 3        1.895968  59.562495  0.017020     0.003797
# 4        1.911610  65.885618  0.022817     0.007601
# ...           ...        ...       ...          ...
# 3412   412.898242  47.539369  5.555777     7.989802
# 3413   410.034924  43.383576  3.892793     7.170400
# 3414   407.863119  43.926493  2.620510     6.260422
# 3415   404.451644  39.864282  0.876692     5.183676
# 3416   403.693163  46.677973  0.392314     4.225404
#
# [3417 rows x 16 columns]

# %%
#Plotting graphs for SMA, EMA, RSI, MACD and MACD_SIGNAL just change the parameter to see the graphs of different indicators
analyzer.plot_TI('SMA')

# %%
analyzer.decompose()

# %%
# Calculating and Visualizing 3 different finacial meterics like Daily return, Cumilative return and annualized volitilty
analyzer.metrics()
